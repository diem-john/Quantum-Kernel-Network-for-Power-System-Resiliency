# %% [markdown]
# # Step 1: Preprocessing the Taipower Target Data

# %%
import pandas as pd
import numpy as np

# %%
# Load the data
df_taipower = pd.read_csv('data/001.csv')

# 1. Rename columns to English immediately
column_mapping = {
    '項次': 'Incident_ID',
    '發生時間': 'Time_Occurred',
    '事故名稱': 'Incident_Description',
    '停電戶數': 'Households_Affected',
    '復電時間': 'Time_Restored'
}
df_taipower.rename(columns=column_mapping, inplace=True)

# 2. Define weather-relevant keywords (Keep these in Chinese to match the raw text)
weather_keywords = ['饋線事故停電', '饋線全停', '分歧開關跳脫', '欠相', '斷線', '過流電驛動作', '差動電驛動作', '51動作', '51N動作', '斷路器跳脫', '越級跳脫']
pattern = '|'.join(weather_keywords)

# 3. Filter for relevant incidents using the new English column name
df_filtered = df_taipower[df_taipower['Incident_Description'].str.contains(pattern, na=False)].copy()

# 4. Parse Timestamps
df_filtered['Timestamp'] = pd.to_datetime(df_filtered['Time_Occurred'], format='%Y%m%dT%H%M%S')

# 5. Create the Binary Target Label
df_filtered['Target_Failure'] = 1 

# 6. Extract Location Entities
import re
def extract_location(text):
    match = re.search(r'(.*?)(變電所|服務區|園區)', text)
    if match:
        return match.group(1) + match.group(2)
    return text

df_filtered['Location_Entity'] = df_filtered['Incident_Description'].apply(extract_location)

# Clean up the dataframe to show only the engineered columns we need
final_columns = ['Incident_ID', 'Timestamp', 'Location_Entity', 'Households_Affected', 'Target_Failure']
df_clean_target = df_filtered[final_columns]

print(df_clean_target.head())
# Out:
#     Incident_ID           Timestamp Location_Entity Households_Affected  \
# 0             1 2024-12-25 23:27:00           榮成變電所                   1
# 4             5 2024-12-10 11:30:00           西螺服務區                  10
# 14           15 2024-11-02 10:22:00          中部科學園區                 112
# 27           28 2024-10-01 19:30:00          中部科學園區                   1
# 28           29 2024-09-28 18:15:00            興變電所               3,230
#
#     Target_Failure
# 0                1
# 4                1
# 14               1
# 27               1
# 28               1

# %%
df_clean_target
# Out:
#      Incident_ID           Timestamp          Location_Entity  \
# 0              1 2024-12-25 23:27:00                    榮成變電所
# 4              5 2024-12-10 11:30:00                    西螺服務區
# 14            15 2024-11-02 10:22:00                   中部科學園區
# 27            28 2024-10-01 19:30:00                   中部科學園區
# 28            29 2024-09-28 18:15:00                     興變電所
# 35            36 2024-09-19 01:01:00                    中正變電所
# 37            38 2024-09-16 17:55:00                    成都變電所
# 44            45 2024-09-01 05:12:00                  新豐配電變電所
# 51            52 2024-07-31 02:40:00                  內惟配電變電所
# 55            56 2024-07-16 14:04:00                    成都變電所
# 59            60 2024-07-01 15:49:00                  永華二次變電所
# 63            64 2024-06-26 15:46:00                  關西二次變電所
# 64            65 2024-06-24 09:29:00                  源海二次變電所
# 65            66 2024-06-23 04:44:00                  四湖配電變電所
# 66            67 2024-06-21 15:47:00                新高港超高壓變電所
# 71            72 2024-06-11 06:48:00                  九曲配電變電所
# 78            79 2024-05-05 12:47:00                    崙背變電所
# 79            80 2024-05-02 19:16:00                    常德變電所
# 83            84 2024-04-25 06:54:00                  嶺口二次變電所
# 85            86 2024-04-18 05:25:00       港南21線事故引起#1M越級跳脫停電
# 88            89 2024-03-30 00:33:00  蘇澳六萬九仟伏特#2匯流排差動電驛動作停電事故
# 90            91 2024-03-25 23:08:00                  龍明配電變電所
# 97            98 2024-02-29 12:22:00                  嶺口二次變電所
# 98            99 2024-02-24 00:48:00                  龍明配電變電所
# 101          102 2024-01-05 09:14:00                  新工配電變電所
#
#     Households_Affected  Target_Failure
# 0                     1               1
# 4                    10               1
# 14                  112               1
# 27                    1               1
# 28                3,230               1
# 35                3,093               1
# 37                1,915               1
# 44                    1               1
# 51                  253               1
# 55                2,350               1
# 59               10,627               1
# 63                6,356               1
# 64                3,763               1
# 65                1,495               1
# 66                  625               1
# 71                1,355               1
# 78                4,975               1
# 79                   19               1
# 83                1,208               1
# 85               18,258               1
# 88                7,408               1
# 90                    1               1
# 97                1,176               1
# 98                    1               1
# 101                  13               1

# %%
df_filtered
# Out:
#      Incident_ID    Time_Occurred              Incident_Description  \
# 0              1  20241225T232700            榮成變電所第59條饋線全停逾時一小時以上事故
# 4              5  20241210T113000                  西螺服務區南下休息站欠相停電事故
# 14            15  20241102T102200                中部科學園區編號H467饋線事故停電
# 27            28  20241001T193000          中部科學園區編號H875饋線事故停電(聯亞科技)
# 28            29  20240928T181500  興變電所9I28饋線相間過流電驛動作造成饋線斷路器跳脫，事故停電
# 35            36  20240919T010100                   中正變電所第51號饋線事故停電
# 37            38  20240916T175500                   成都變電所第62號饋線事故停電
# 44            45  20240901T051200                  新豐配電變電所第59饋線事故停電
# 51            52  20240731T024000             內惟配電變電所第74饋線斷路器跳脫事故停電
# 55            56  20240716T140400                    成都變電所第62饋線事故停電
# 59            60  20240701T154900            永華二次變電所4號聯絡斷路器越級跳脫停電事故
# 63            64  20240626T154600               關西二次變電所配電饋線越級跳脫事故停電
# 64            65  20240624T092900           源海二次變電所#2主變壓器全停，5饋線全停電。
# 65            66  20240623T044400         四湖配電變電所 飛 11 饋線51動作斷線欠相事故
# 66            67  20240621T154700          新高港超高壓變電所#28饋線過流電驛動作事故停電
# 71            72  20240611T064800                 九曲配電變電所BM26饋線事故停電
# 78            79  20240505T124700         崙背變電所崙9饋線51N動作斷路器(CB)跳脫事故
# 79            80  20240502T191600                     常德變電所70饋線事故停電
# 83            84  20240425T065400                 嶺口二次變電所BZ38饋線事故停電
# 85            86  20240418T052500                港南21線事故引起#1M越級跳脫停電
# 88            89  20240330T003300           蘇澳六萬九仟伏特#2匯流排差動電驛動作停電事故
# 90            91  20240325T230800                  龍明配電變電所第6B饋線事故停電
# 97            98  20240229T122200                 嶺口二次變電所BZ38饋線事故停電
# 98            99  20240224T004800            龍明配電變電所第56饋線分歧開關跳脫事故停電
# 101          102  20240105T091400                  新工配電變電所第76饋線事故停電
#
#     Households_Affected    Time_Restored           Timestamp  Target_Failure  \
# 0                     1  20241226T020700 2024-12-25 23:27:00               1
# 4                    10  20241210T160000 2024-12-10 11:30:00               1
# 14                  112  20241102T102200 2024-11-02 10:22:00               1
# 27                    1  20241001T194000 2024-10-01 19:30:00               1
# 28                3,230  20240928T184200 2024-09-28 18:15:00               1
# 35                3,093  20240919T022000 2024-09-19 01:01:00               1
# 37                1,915  20240916T183900 2024-09-16 17:55:00               1
# 44                    1  20240901T051600 2024-09-01 05:12:00               1
# 51                  253  20240731T032900 2024-07-31 02:40:00               1
# 55                2,350  20240716T140900 2024-07-16 14:04:00               1
# 59               10,627  20240701T163000 2024-07-01 15:49:00               1
# 63                6,356  20240626T203000 2024-06-26 15:46:00               1
# 64                3,763  20240624T094400 2024-06-24 09:29:00               1
# 65                1,495  20240623T064600 2024-06-23 04:44:00               1
# 66                  625  20240621T155400 2024-06-21 15:47:00               1
# 71                1,355  20240611T103000 2024-06-11 06:48:00               1
# 78                4,975  20240505T170200 2024-05-05 12:47:00               1
# 79                   19  20240502T191800 2024-05-02 19:16:00               1
# 83                1,208  20240425T103000 2024-04-25 06:54:00               1
# 85               18,258  20240418T061000 2024-04-18 05:25:00               1
# 88                7,408  20240330T003700 2024-03-30 00:33:00               1
# 90                    1  20240326T063000 2024-03-25 23:08:00               1
# 97                1,176  20240229T150500 2024-02-29 12:22:00               1
# 98                    1  20240224T020000 2024-02-24 00:48:00               1
# 101                  13  20240105T121000 2024-01-05 09:14:00               1
#
#              Location_Entity
# 0                      榮成變電所
# 4                      西螺服務區
# 14                    中部科學園區
# 27                    中部科學園區
# 28                      興變電所
# 35                     中正變電所
# 37                     成都變電所
# 44                   新豐配電變電所
# 51                   內惟配電變電所
# 55                     成都變電所
# 59                   永華二次變電所
# 63                   關西二次變電所
# 64                   源海二次變電所
# 65                   四湖配電變電所
# 66                 新高港超高壓變電所
# 71                   九曲配電變電所
# 78                     崙背變電所
# 79                     常德變電所
# 83                   嶺口二次變電所
# 85        港南21線事故引起#1M越級跳脫停電
# 88   蘇澳六萬九仟伏特#2匯流排差動電驛動作停電事故
# 90                   龍明配電變電所
# 97                   嶺口二次變電所
# 98                   龍明配電變電所
# 101                  新工配電變電所

# %%
locs = df_filtered.Location_Entity.values
locs
# Out:
# array(['榮成變電所', '西螺服務區', '中部科學園區', '中部科學園區', '興變電所', '中正變電所', '成都變電所',
#        '新豐配電變電所', '內惟配電變電所', '成都變電所', '永華二次變電所', '關西二次變電所', '源海二次變電所',
#        '四湖配電變電所', '新高港超高壓變電所', '九曲配電變電所', '崙背變電所', '常德變電所', '嶺口二次變電所',
#        '港南21線事故引起#1M越級跳脫停電', '蘇澳六萬九仟伏特#2匯流排差動電驛動作停電事故', '龍明配電變電所',
#        '嶺口二次變電所', '龍明配電變電所', '新工配電變電所'], dtype=object)

# %% [markdown]
# # Step 2: The Spatial-Temporal Merge

# %%
import io

# %%
# 1. Load your Geomap Data
geomap_csv = """name,type,latitude,longitude,confidence
榮成變電所,substation,25.05482,121.13183,0.95
西螺服務區,place,23.7987,120.4665,0.85
中部科學園區,place,24.2173,120.6997,0.80
中部科學園區,place,24.2173,120.6997,0.80
興變電所,substation,23.5,120.8,0.40
中正變電所,substation,25.0329,121.5654,0.40
成都變電所,substation,24.9936,121.3010,0.35
新豐配電變電所,substation,24.9053,120.9839,0.75
內惟配電變電所,substation,22.6663,120.2862,0.75
成都變電所,substation,24.9936,121.3010,0.35
永華二次變電所,substation,22.9908,120.2133,0.75
關西二次變電所,substation,24.7920,121.1760,0.80
源海二次變電所,substation,25.0330,121.5654,0.30
四湖配電變電所,substation,23.6367,120.2250,0.80
新高港超高壓變電所,substation,22.570017,120.407833,0.90
九曲配電變電所,substation,22.9900,120.2000,0.35
崙背變電所,substation,23.7580,120.3530,0.80
常德變電所,substation,25.0600,121.5200,0.30
嶺口二次變電所,substation,22.7580,120.3600,0.75
港南21線事故引起#1M越級跳脫停電,event,,
蘇澳六萬九仟伏特#2匯流排差動電驛動作停電事故,event,,
龍明配電變電所,substation,24.9930,121.2960,0.60
嶺口二次變電所,substation,22.7580,120.3600,0.75
龍明配電變電所,substation,24.9930,121.2960,0.60
新工配電變電所,substation,24.8138,120.9675,0.60"""

df_geo = pd.read_csv(io.StringIO(geomap_csv))

# %%
d

# %%
# Drop duplicates from your list to prevent merging errors
df_geo = df_geo.drop_duplicates(subset=['name'])

# 2. Merge Coordinates onto the Target Data
df_spatial = pd.merge(df_clean_target, df_geo[['name', 'latitude', 'longitude']], 
                      left_on='Location_Entity', right_on='name', how='left')

# Drop events where coordinates are missing (NaN)
df_spatial = df_spatial.dropna(subset=['latitude', 'longitude']).copy()
df_spatial = df_spatial.drop(columns=['name'])

# 3. Define the Haversine Distance Formula (Earth Curvature Math)
def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0 # Earth radius in kilometers
    dLat = np.radians(lat2 - lat1)
    dLon = np.radians(lon2 - lon1)
    a = np.sin(dLat/2)**2 + np.cos(np.radians(lat1)) * np.cos(np.radians(lat2)) * np.sin(dLon/2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
    return R * c

# 4. Load JMA Typhoon Data
df_storm = pd.read_csv('data/typhoon_data.csv')

# Ensure JMA timestamps are parsed correctly (Handling DD/MM/YYYY HH:MM)
df_storm['Timestamp'] = pd.to_datetime(df_storm['Date'], format='%d/%m/%Y %H:%M', errors='coerce')

# Drop any rows where parsing failed (optional cleanup)
df_storm = df_storm.dropna(subset=['Timestamp']).reset_index(drop=True)

# 5. Spatial-Temporal Alignment Function
def align_storm_features(fault_row, storm_df):
    # Calculate the absolute time difference between the power outage and all storm records
    time_diff = (storm_df['Timestamp'] - fault_row['Timestamp']).abs()
    
    # Find the index of the JMA record closest in time to the outage
    closest_idx = time_diff.idxmin()
    closest_storm = storm_df.loc[closest_idx]
    
    # Calculate physical distance from the substation to the storm eye
    dist_km = haversine(fault_row['latitude'], fault_row['longitude'], 
                        closest_storm['lat'], closest_storm['lng'])
    
    return pd.Series({
        'Distance_to_Eye_km': round(dist_km, 2),
        'Wind_Speed': closest_storm['wind'], 
        'Pressure': closest_storm['pressure'],    
        'Time_Delta_Hours': round(time_diff.min().total_seconds() / 3600, 2)
    })

# 6. Apply the alignment function to build the final Feature Matrix
print("Aligning spatial-temporal storm tracks with grid failures...")
storm_features = df_spatial.apply(lambda row: align_storm_features(row, df_storm), axis=1)

# Concatenate the features (X) with the target (y)
final_dataset = pd.concat([df_spatial, storm_features], axis=1)

print(f"\nFinal Dataset Ready for QKN: {len(final_dataset)} verified events.")
# Out:
# Aligning spatial-temporal storm tracks with grid failures...
#
# Final Dataset Ready for QKN: 23 verified events.

# %%
final_dataset
# Out:
#     Incident_ID           Timestamp Location_Entity Households_Affected  \
# 0             1 2024-12-25 23:27:00           榮成變電所                   1
# 1             5 2024-12-10 11:30:00           西螺服務區                  10
# 2            15 2024-11-02 10:22:00          中部科學園區                 112
# 3            28 2024-10-01 19:30:00          中部科學園區                   1
# 4            29 2024-09-28 18:15:00            興變電所               3,230
# 5            36 2024-09-19 01:01:00           中正變電所               3,093
# 6            38 2024-09-16 17:55:00           成都變電所               1,915
# 7            45 2024-09-01 05:12:00         新豐配電變電所                   1
# 8            52 2024-07-31 02:40:00         內惟配電變電所                 253
# 9            56 2024-07-16 14:04:00           成都變電所               2,350
# 10           60 2024-07-01 15:49:00         永華二次變電所              10,627
# 11           64 2024-06-26 15:46:00         關西二次變電所               6,356
# 12           65 2024-06-24 09:29:00         源海二次變電所               3,763
# 13           66 2024-06-23 04:44:00         四湖配電變電所               1,495
# 14           67 2024-06-21 15:47:00       新高港超高壓變電所                 625
# 15           72 2024-06-11 06:48:00         九曲配電變電所               1,355
# 16           79 2024-05-05 12:47:00           崙背變電所               4,975
# 17           80 2024-05-02 19:16:00           常德變電所                  19
# 18           84 2024-04-25 06:54:00         嶺口二次變電所               1,208
# 21           91 2024-03-25 23:08:00         龍明配電變電所                   1
# 22           98 2024-02-29 12:22:00         嶺口二次變電所               1,176
# 23           99 2024-02-24 00:48:00         龍明配電變電所                   1
# 24          102 2024-01-05 09:14:00         新工配電變電所                  13
#
#     Target_Failure   latitude   longitude  Distance_to_Eye_km  Wind_Speed  \
# 0                1  25.054820  121.131830             1187.29         0.0
# 1                1  23.798700  120.466500             1201.36         0.0
# 2                1  24.217300  120.699700             1193.23         0.0
# 3                1  24.217300  120.699700             1193.23         0.0
# 4                1  23.500000  120.800000             1159.44         0.0
# 5                1  25.032900  121.565400             1146.63         0.0
# 6                1  24.993600  121.301000             1168.96         0.0
# 7                1  24.905300  120.983900             1194.22         0.0
# 8                1  22.666300  120.286200             1189.39         0.0
# 9                1  24.993600  121.301000             1168.96         0.0
# 10               1  22.990800  120.213300             1203.88         0.0
# 11               1  24.792000  121.176000             1171.44         0.0
# 12               1  25.033000  121.565400             1146.64         0.0
# 13               1  23.636700  120.225000             1219.97         0.0
# 14               1  22.570017  120.407833             1175.16         0.0
# 15               1  22.990000  120.200000             1205.19         0.0
# 16               1  23.758000  120.353000             1211.14         0.0
# 17               1  25.060000  121.520000             1152.05         0.0
# 18               1  22.758000  120.360000             1183.90         0.0
# 21               1  24.993000  121.296000             1169.39         0.0
# 22               1  22.758000  120.360000             1183.90         0.0
# 23               1  24.993000  121.296000             1169.39         0.0
# 24               1  24.813800  120.967500             1191.76         0.0
#
#     Pressure  Time_Delta_Hours
# 0     1006.0          17867.45
# 1     1006.0          17495.50
# 2     1006.0          16582.37
# 3     1006.0          15823.50
# 4     1006.0          15750.25
# 5     1006.0          15517.02
# 6     1006.0          15461.92
# 7     1006.0          15089.20
# 8     1006.0          14318.67
# 9     1006.0          13970.07
# 10    1006.0          13611.82
# 11    1006.0          13491.77
# 12    1006.0          13437.48
# 13    1006.0          13408.73
# 14    1006.0          13371.78
# 15    1006.0          13122.80
# 16    1006.0          12240.78
# 17    1006.0          12175.27
# 18    1006.0          11994.90
# 21    1006.0          11267.13
# 22    1006.0          10656.37
# 23    1006.0          10524.80
# 24    1006.0           9333.23
